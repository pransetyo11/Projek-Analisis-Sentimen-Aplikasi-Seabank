# %% [markdown]
# # **Import Library**

# %%
# !pip install google-play-scraper
# Out:
# Requirement already satisfied: google-play-scraper in /usr/local/lib/python3.12/dist-packages (1.2.7)

# %%
from google_play_scraper import app, reviews, Sort, reviews_all
import csv
import pandas as pd

# %% [markdown]
# # **Scraping Data**

# %%
# Mengambil semua ulasan dari aplikasi SeaBank dengan ID 'id.co.bankbkemobile.digitalbank' di Google Play Store.
scrapreview = reviews_all(
    'id.co.bankbkemobile.digitalbank',
    lang='id',
    country='id',
    sort=Sort.MOST_RELEVANT,
    count=12000
)

# %%
# Menyimpan ulasan dalam file CSV
with open('ulasan_aplikasi.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Review'])
    for review in scrapreview:
        writer.writerow([review['content']])

# %%
app_reviews_df = pd.DataFrame(scrapreview)
app_reviews_df.shape
app_reviews_df.head()
app_reviews_df.to_csv('ulasan_aplikasi.csv', index=False)

# %%
# Membuat DataFrame dari hasil scrapreview
app_reviews_df = pd.DataFrame(scrapreview)

# Menghitung jumlah baris dan kolom dalam DataFrame
jumlah_ulasan, jumlah_kolom = app_reviews_df.shape

# %%
# Menampilkan lima baris pertama dari DataFrame app_reviews_df
app_reviews_df.head()
# Out:
#                                reviewId         userName  \
# 0  e7f67ea8-376c-4f11-860b-7cde54131967  Pengguna Google
# 1  9996cd5a-f41d-4e1e-84b2-f2665492ab32  Pengguna Google
# 2  65c7fb0b-5cd5-45a5-8e13-6c569c76fd4a  Pengguna Google
# 3  9e1016ed-f492-4239-8379-aec2c0112038  Pengguna Google
# 4  801799e5-c0c6-4450-a8e0-2db0efe4ccdc  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  tempat bagus juga harga terjangkau,programnya ...      5            204
# 1  TEempat bagus juga harga terjangkau,programnya...      5             14
# 2  Praktis & oke juga harga,terjangkau. Programny...      5             16
# 3  TEmpat bagus dan praktis juga harganya terjang...      5              3
# 4  Proses pendaftaran sangat mudah & cepat hanya ...      5             30
#
#   reviewCreatedVersion                  at  \
# 0               3.36.0 2026-02-01 09:36:59
# 1               3.37.0 2026-02-04 15:50:10
# 2               3.36.0 2026-02-02 06:32:09
# 3               3.36.0 2026-01-23 10:19:49
# 4               3.36.0 2026-01-28 06:33:38
#
#                                         replyContent           repliedAt  \
# 0  Hi Sobat SeaBank. Mohon maaf atas ketidaknyama... 2026-02-01 10:25:09
# 1  Hi Sobat SeaBank. Mohon maaf atas ketidaknyama... 2026-02-04 16:12:59
# 2  Hai Sobat SeaBank, mohon maaf jika pelayanan k... 2026-02-01 06:25:31
# 3  Hai Sobat SeaBank, mohon maaf. Pastikan Aplika... 2026-01-23 11:08:44
# 4  Hi Sobat SeaBank. Mohon maaf atas ketidaknyama... 2026-01-28 08:26:26
#
#   appVersion
# 0     3.36.0
# 1     3.37.0
# 2     3.36.0
# 3     3.36.0
# 4     3.36.0

# %%
# Menampilkan informasi dataframe
app_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 238500 entries, 0 to 238499
# Data columns (total 11 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   reviewId              238500 non-null  object
#  1   userName              238500 non-null  object
#  2   userImage             238500 non-null  object
#  3   content               238500 non-null  object
#  4   score                 238500 non-null  int64
#  5   thumbsUpCount         238500 non-null  int64
#  6   reviewCreatedVersion  220106 non-null  object
#  7   at                    238500 non-null  datetime64[ns]
#  8   replyContent          68598 non-null   object
#  9   repliedAt             68598 non-null   datetime64[ns]
#  10  appVersion            220106 non-null  object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 20.0+ MB
